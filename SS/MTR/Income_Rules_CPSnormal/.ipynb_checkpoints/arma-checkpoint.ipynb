# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from numpy import linalg as la
from scipy import optimize as op
from scipy.stats import norm
from scipy.stats import multivariate_normal
# %matplotlib inline

N = norm.pdf



time_series_a = pd.read_csv('Bendpoints.csv')
# time_series_a = time_series_a[time_series_a['Year'] < 2017] 45 projected

time_series_a_1 = time_series_a['Bend_pt1'].as_matrix()
time_series_a_2 = time_series_a['Bend_pt2'].as_matrix()

time_series_c = pd.read_csv('averagewages.csv')
time_series_c = time_series_c['Avg_Wage'].as_matrix()


def arma_likelihood(time_series, phis=np.array([]), thetas=np.array([]), mu=0., sigma=1.):
    """
    Return the log-likelihood of the ARMA model parameters, given the time series.
    
    Parameters
    ----------
    time_series : ndarray of shape (n,1)
        The time series in question, z_t
    phis : ndarray of shape (p,)
        The phi parameters
    thetas : ndarray of shape (q,)
        The theta parameters
    mu : float
        The parameter mu
    sigma : float
        The standard deviation of the a_t random variables
    
    Returns
    -------
    log_likelihood : float
        The log-likelihood of the model
    """
    n = len(time_series)
    p = len(phis)
    q = len(thetas)
    r = max(p, q+1)
    
    # initialize F, H, and Q matrices
    H = np.zeros(r)
    H[0] = 1
    H[1:1+q] = thetas
    
    F = np.diag([1.]*(r-1),-1)
    F[0,:p] = phis
    
    Q = np.zeros((r,r))
    Q[0,0] = sigma**2
    
    # initialize xhat and P
    xhat = np.zeros(r)
    temp = np.eye(r**2) - np.kron(F,F)
    P = la.solve(temp, Q.flatten()).reshape(r,r)
    
    log_likelihood = 0.
    
    for i in range(n):
        z = time_series[i] - mu
        log_likelihood += np.log(N(time_series[i],
                                   loc=(H.dot(xhat) + mu),
                                   scale=np.sqrt(np.abs(H.dot(P).dot(H.T)))))
        
        w = multivariate_normal.rvs(cov=Q)
        
        # update step
        y = z - H.dot(xhat)
        S = H.dot(P).dot(H.T) # + R? (observation error)
        K = P.dot(H.T)/S # S should be a scalar
        xhat += K.dot(y)
        P = np.dot(np.eye(r) - np.outer(K,H), P)
        
        xhat = F.dot(xhat)# + w
        P = F.dot(P).dot(F.T) + Q
        
        
    return log_likelihood




def arma_fit(time_series):
    """
    Return the ARMA model that minimizes AICc for the given time series,
    subject to p,q <= 3.
    
    Parameters
    ----------
    time_series : ndarray of shape (n,1)
        The time series in question, z_t
    
    Returns
    -------
    phis : ndarray of shape (p,)
        The phi parameters
    thetas : ndarray of shape (q,)
        The theta parameters
    mu : float
        The parameter mu
    sigma : float
        The standard deviation of the a_t random variables
    """
    n = len(time_series)
    
    best_AIC = np.inf # lowest = best
    best_params = 0 # parameters
    best_p = 0
    best_q = 0
    
    for p in range(0,4):
        for q in range(0,4):
            print 'p = %i, q = %i' % (p,q)
            k = p + q + 2
            
            def f(x): # negative log likelihood
                return -arma_likelihood(time_series, phis = x[:p], thetas=x[p:p+q],
                                        mu=x[-2], sigma=x[-1])
            x0 = np.zeros(p+q+2)
            x0[-2] = time_series.mean()
            x0[-1] = time_series.std()
            sol = op.fmin(f, x0, maxiter=10000, maxfun=10000)
            
            AIC = 2*f(sol) + 2*k*(1 + (k+1)/float(n-k))
            
            if AIC < best_AIC:
                best_AIC = AIC
                best_params = sol
                best_p = p
                best_q = q
                
    print 'Best AIC:', best_AIC
    return (best_params[:best_p], best_params[best_p:best_p+best_q],
            best_params[-2], best_params[-1])




phis_a1, thetas_a1, mu_a1, sigma_a1 = arma_fit(time_series_a_1)
print 'p =', len(phis_a1)
print 'q =', len(thetas_a1)
print 'phis:', phis_a1
print 'thetas:', thetas_a1
print 'mu:', mu_a1
print 'sigma:', sigma_a1






phis_c, thetas_c, mu_c, sigma_c = arma_fit(time_series_c)
print 'p =', len(phis_c)
print 'q =', len(thetas_c)
print 'phis:', phis_c
print 'thetas:', thetas_c
print 'mu:', mu_c
print 'sigma:', sigma_c


phis_a2, thetas_a2, mu_a2, sigma_a2 = arma_fit(time_series_a_2)
print 'p =', len(phis_a2)
print 'q =', len(thetas_a2)
print 'phis:', phis_a2
print 'thetas:', thetas_a2
print 'mu:', mu_a2
print 'sigma:', sigma_a2




def arma_forecast(time_series, phis=np.array([]), thetas=np.array([]), mu=0., sigma=1., future_periods=20):
    """
    Return forecasts for a time series modeled with the given ARMA model.
    
    Parameters
    ----------
    time_series : ndarray of shape (n,1)
        The time series in question, z_t
    phis : ndarray of shape (p,)
        The phi parameters
    thetas : ndarray of shape (q,)
        The theta parameters
    mu : float
        The parameter mu
    sigma : float
        The standard deviation of the a_t random variables
    future_periods : int
        The number of future periods to return
    
    Returns
    -------
    e_vals : ndarray of shape (future_periods,)
        The expected values of z for times n+1, ..., n+future_periods
    sigs : ndarray of shape (future_periods,)
        The standard deviations of z for times n+1, ..., n+future_periods
    """
    n = len(time_series)
    p = len(phis)
    q = len(thetas)
    r = max(p, q+1)
    
    # initialize F, H, and Q matrices
    H = np.zeros(r)
    H[0] = 1
    H[1:1+q] = thetas
    
    F = np.diag([1.]*(r-1),-1)
    F[0,:p] = phis
    
    Q = np.zeros((r,r))
    Q[0,0] = sigma**2
    
    # initialize xhat and P
    xhat = np.zeros(r)
    temp = np.eye(r**2) - np.kron(F,F)
    P = la.solve(temp, Q.flatten()).reshape(r,r)
    
    for i in range(n):
        z = time_series[i] - mu
        
        # update step
        y = z - H.dot(xhat)
        S = H.dot(P).dot(H.T) # + R? (observation error)
        K = P.dot(H.T)/S # S should be a scalar
        xhat += K.dot(y)
        P = np.dot(np.eye(r) - np.outer(K,H), P)
        
        if i == n-1:
            break
        
        # predict step
        xhat = F.dot(xhat)
        P = F.dot(P).dot(F.T) + Q
    
    e_vals = []
    sigs = []
    for i in range(future_periods):
        xhat = F.dot(xhat)
        P = F.dot(P).dot(F.T) + Q
        
        e_vals.append(H.dot(xhat) + mu)
        sigs.append(np.sqrt(H.dot(P).dot(H.T)))
    
        
    return np.array(e_vals), np.array(sigs)






n = len(time_series_a_1)
e_vals1, sigs1 = arma_forecast(time_series_a_1, phis_a1, thetas_a1, mu_a1, sigma_a1, 45)
plt.plot(time_series_a_1)
plt.plot(range(n,n+45), e_vals1)
plt.plot(range(n,n+45), e_vals1 + sigs1, ls='-')
plt.plot(range(n,n+45), e_vals1 - sigs1, ls='-')
plt.plot(range(n,n+45), e_vals1 + 2*sigs1, ls='-')
plt.plot(range(n,n+45), e_vals1 - 2*sigs1, ls='-')
plt.show()



n = len(time_series_c)
e_vals, sigs = arma_forecast(time_series_c, phis_c, thetas_c, mu_c, sigma_c, 45)
plt.plot(time_series_c)
plt.plot(range(n,n+45), e_vals)
plt.plot(range(n,n+45), e_vals + sigs, ls='-')
plt.plot(range(n,n+45), e_vals - sigs, ls='-')
plt.plot(range(n,n+45), e_vals + 2*sigs, ls='-')
plt.plot(range(n,n+45), e_vals - 2*sigs, ls='-')
plt.show()

n = len(time_series_a_2)
e_vals2, sigs2 = arma_forecast(time_series_a_2, phis_a2, thetas_a2, mu_a2, sigma_a2, 45)
plt.plot(time_series_a_2)
plt.plot(range(n,n+45), e_vals2)
plt.plot(range(n,n+45), e_vals2 + sigs2, ls='-')
plt.plot(range(n,n+45), e_vals2 - sigs2, ls='-')
plt.plot(range(n,n+45), e_vals2 + 2*sigs2, ls='-')
plt.plot(range(n,n+45), e_vals2 - 2*sigs2, ls='-')
plt.show()
# Out:
# p = 0, q = 0
# Optimization terminated successfully.
#          Current function value: 332.245609
#          Iterations: 38
#          Function evaluations: 77
# p = 0, q = 1
# Optimization terminated successfully.
#          Current function value: 303.422066
#          Iterations: 128
#          Function evaluations: 228
# p = 0, q = 2
# Optimization terminated successfully.
#          Current function value: 277.489273
#          Iterations: 271
#          Function evaluations: 464
# p = 0, q = 3
# Optimization terminated successfully.
#          Current function value: 256.158285
#          Iterations: 517
#          Function evaluations: 851
# p = 1, q = 0
# /home/parker/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:73: RuntimeWarning: divide by zero encountered in log
# Optimization terminated successfully.
#          Current function value: 180.030774
#          Iterations: 178
#          Function evaluations: 314
# p = 1, q = 1
# Optimization terminated successfully.
#          Current function value: 204.038459
#          Iterations: 313
#          Function evaluations: 539
# p = 1, q = 2
# Optimization terminated successfully.
#          Current function value: 192.212741
#          Iterations: 1020
#          Function evaluations: 1652
# p = 1, q = 3
# Optimization terminated successfully.
#          Current function value: 173.469667
#          Iterations: 1226
#          Function evaluations: 1900
# p = 2, q = 0
# Optimization terminated successfully.
#          Current function value: 172.264524
#          Iterations: 347
#          Function evaluations: 593
# p = 2, q = 1
# Optimization terminated successfully.
#          Current function value: 178.739211
#          Iterations: 939
#          Function evaluations: 1530
# p = 2, q = 2
# Warning: Maximum number of function evaluations has been exceeded.
# p = 2, q = 3
# Optimization terminated successfully.
#          Current function value: 173.546455
#          Iterations: 2013
#          Function evaluations: 3083
# p = 3, q = 0
# Optimization terminated successfully.
#          Current function value: 172.155786
#          Iterations: 945
#          Function evaluations: 1537
# p = 3, q = 1
# Optimization terminated successfully.
#          Current function value: 198.969168
#          Iterations: 863
#          Function evaluations: 1380
# p = 3, q = 2
# Optimization terminated successfully.
#          Current function value: 172.100382
#          Iterations: 1617
#          Function evaluations: 2461
# p = 3, q = 3
# Optimization terminated successfully.
#          Current function value: 171.690196
#          Iterations: 1860
#          Function evaluations: 2748
# Best AIC: 353.459279913
# p = 2
# q = 0
# phis: [ 1.5685934  -0.54797288]
# thetas: []
# mu: 126.201343647
# sigma: 9.02655631854
# p = 0, q = 0
# Optimization terminated successfully.
#          Current function value: 847.348367
#          Iterations: 50
#          Function evaluations: 110
# p = 0, q = 1
# Optimization terminated successfully.
#          Current function value: 799.384446
#          Iterations: 153
#          Function evaluations: 285
# p = 0, q = 2
# Optimization terminated successfully.
#          Current function value: 754.930308
#          Iterations: 349
#          Function evaluations: 605
# p = 0, q = 3
# Optimization terminated successfully.
#          Current function value: 718.477119
#          Iterations: 552
#          Function evaluations: 906
# p = 1, q = 0
# Optimization terminated successfully.
#          Current function value: 563.768060
#          Iterations: 176
#          Function evaluations: 324
# p = 1, q = 1
# Optimization terminated successfully.
#          Current function value: 553.886477
#          Iterations: 410
#          Function evaluations: 710
# p = 1, q = 2
# Optimization terminated successfully.
#          Current function value: 552.387513
#          Iterations: 702
#          Function evaluations: 1153
# p = 1, q = 3
# Optimization terminated successfully.
#          Current function value: 551.941099
#          Iterations: 1395
#          Function evaluations: 2202
# p = 2, q = 0
# Optimization terminated successfully.
#          Current function value: 552.799472
#          Iterations: 406
#          Function evaluations: 702
# p = 2, q = 1
# Optimization terminated successfully.
#          Current function value: 552.465551
#          Iterations: 669
#          Function evaluations: 1098
# p = 2, q = 2
# Optimization terminated successfully.
#          Current function value: 552.495371
#          Iterations: 849
#          Function evaluations: 1393
# p = 2, q = 3
# Optimization terminated successfully.
#          Current function value: 552.347325
#          Iterations: 1716
#          Function evaluations: 2650
# p = 3, q = 0
# Optimization terminated successfully.
#          Current function value: 552.555975
#          Iterations: 819
#          Function evaluations: 1328
# p = 3, q = 1
# Optimization terminated successfully.
#          Current function value: 552.611527
#          Iterations: 991
#          Function evaluations: 1594
# p = 3, q = 2
# Optimization terminated successfully.
#          Current function value: 551.373949
#          Iterations: 1649
#          Function evaluations: 2529
# p = 3, q = 3
# Warning: Maximum number of function evaluations has been exceeded.
# Best AIC: 1114.1623244
# p = 2
# q = 0
# phis: [ 1.53203248 -0.51296986]
# thetas: []
# mu: 441.735628439
# sigma: 373.587362145
# p = 0, q = 0
# Optimization terminated successfully.
#          Current function value: 416.671383
#          Iterations: 42
#          Function evaluations: 85
# p = 0, q = 1
# Optimization terminated successfully.
#          Current function value: 387.852868
#          Iterations: 143
#          Function evaluations: 263
# p = 0, q = 2
# Optimization terminated successfully.
#          Current function value: 361.905305
#          Iterations: 308
#          Function evaluations: 525
# p = 0, q = 3
# Optimization terminated successfully.
#          Current function value: 340.473918
#          Iterations: 457
#          Function evaluations: 747
# p = 1, q = 0
# Optimization terminated successfully.
#          Current function value: 264.032539
#          Iterations: 194
#          Function evaluations: 343
# p = 1, q = 1
# Optimization terminated successfully.
#          Current function value: 288.158065
#          Iterations: 302
#          Function evaluations: 527
# p = 1, q = 2
# Optimization terminated successfully.
#          Current function value: 255.523858
#          Iterations: 999
#          Function evaluations: 1620
# p = 1, q = 3
# Warning: Maximum number of function evaluations has been exceeded.
# p = 2, q = 0
# Optimization terminated successfully.
#          Current function value: 255.662311
#          Iterations: 460
#          Function evaluations: 776
# p = 2, q = 1
# Optimization terminated successfully.
#          Current function value: 262.159960
#          Iterations: 1271
#          Function evaluations: 2055
# p = 2, q = 2
# Optimization terminated successfully.
#          Current function value: 261.134433
#          Iterations: 1583
#          Function evaluations: 2705
# p = 2, q = 3
# Optimization terminated successfully.
#          Current function value: 264.079548
#          Iterations: 1594
#          Function evaluations: 2448
# p = 3, q = 0
# Optimization terminated successfully.
#          Current function value: 255.549237
#          Iterations: 978
#          Function evaluations: 1573
# p = 3, q = 1
# Optimization terminated successfully.
#          Current function value: 263.371167
#          Iterations: 869
#          Function evaluations: 1435
# p = 3, q = 2
# Optimization terminated successfully.
#          Current function value: 255.497692
#          Iterations: 1668
#          Function evaluations: 2507
# p = 3, q = 3
# Optimization terminated successfully.
#          Current function value: 268.131486
#          Iterations: 2800
#          Function evaluations: 4297
# Best AIC: 520.254854484
# p = 2
# q = 0
# phis: [ 1.58571897 -0.56585622]
# thetas: []
# mu: 761.600264265
# sigma: 53.1678337236

# %%
np.savetxt('bend_pt1_projected', e_vals1)
np.savetxt('bend_pt2_projected', e_vals2)
np.savetxt('avgwageproject_projected', e_vals)
np.savetxt('bend_pt1_projected_sig', sigs1)
np.savetxt('bend_pt2_projected_sig', sigs2)
np.savetxt('avgwageproject_projected_sig', sigs)
